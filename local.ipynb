# %%
from operator import index
import streamlit as st
import plotly.express as px
from pycaret.regression import setup, compare_models, pull, save_model, load_model
import ydata_profiling
import pandas as pd
from streamlit_pandas_profiling import st_profile_report
import os 





df = pd.read_csv("dataset.csv")
st.dataframe(df)


profile = ydata_profiling.ProfileReport(df)


df.head()
# Out:
#    Id                                          Model  Price  Age_08_04     KM  \
# 0   1  TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23  46986
# 1   2  TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23  72937
# 2   3  TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24  41711
# 3   4  TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26  48000
# 4   5    TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30  38500
#
#    HP  Automatic    CC  Doors  Cylinders  Gears  Weight
# 0  90          0  2000      3          4      5    1165
# 1  90          0  2000      3          4      5    1165
# 2  90          0  2000      3          4      5    1165
# 3  90          0  2000      3          4      5    1165
# 4  90          0  2000      3          4      5    1170

# %%
#drop non numeric columns
#find the columns that are non numeric
non_numeric_columns = [col for col in df.columns if df[col].dtype == 'object']
#drop the non numeric columns
df = df.drop(non_numeric_columns, axis=1)
display(df.head())
#save csv of df
df.to_csv('numeric corrola.csv', index=False)

chosen_target = df["Price"]
    
setup(df, target=chosen_target)

best_model = compare_models()
compare_df = pull()

save_model(best_model, 'best_model')
# Out:
#    Id  Price  Age_08_04     KM  HP  Automatic    CC  Doors  Cylinders  Gears  \
# 0   1  13500         23  46986  90          0  2000      3          4      5
# 1   2  13750         23  72937  90          0  2000      3          4      5
# 2   3  13950         24  41711  90          0  2000      3          4      5
# 3   4  14950         26  48000  90          0  2000      3          4      5
# 4   5  13750         30  38500  90          0  2000      3          4      5
#
#    Weight
# 0    1165
# 1    1165
# 2    1165
# 3    1165
# 4    1170
# <style type="text/css">
# #T_d9666_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d9666">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9666_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d9666_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9666_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9666_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d9666_row0_col1" class="data row0 col1" >836</td>
#     </tr>
#     <tr>
#       <th id="T_d9666_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d9666_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d9666_row1_col1" class="data row1 col1" >Price_y</td>
#     </tr>
#     <tr>
#       <th id="T_d9666_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d9666_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d9666_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_d9666_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d9666_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d9666_row3_col1" class="data row3 col1" >(1436, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_d9666_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d9666_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d9666_row4_col1" class="data row4 col1" >(1436, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_d9666_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d9666_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d9666_row5_col1" class="data row5 col1" >(1005, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_d9666_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d9666_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d9666_row6_col1" class="data row6 col1" >(431, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_d9666_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d9666_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_d9666_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_d9666_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d9666_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_d9666_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d9666_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d9666_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_d9666_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d9666_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d9666_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_d9666_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d9666_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d9666_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_d9666_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d9666_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d9666_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_d9666_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_d9666_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d9666_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_d9666_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d9666_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d9666_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_d9666_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d9666_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d9666_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_d9666_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d9666_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d9666_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_d9666_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d9666_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d9666_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_d9666_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d9666_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d9666_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_d9666_row18_col1" class="data row18 col1" >1a84</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e54e0 th {
#   text-align: left;
# }
# #T_e54e0_row0_col0, #T_e54e0_row1_col0, #T_e54e0_row1_col1, #T_e54e0_row1_col3, #T_e54e0_row2_col0, #T_e54e0_row2_col1, #T_e54e0_row2_col2, #T_e54e0_row2_col3, #T_e54e0_row3_col0, #T_e54e0_row3_col1, #T_e54e0_row3_col2, #T_e54e0_row3_col3, #T_e54e0_row3_col5, #T_e54e0_row3_col6, #T_e54e0_row4_col0, #T_e54e0_row5_col0, #T_e54e0_row5_col1, #T_e54e0_row5_col2, #T_e54e0_row5_col3, #T_e54e0_row6_col0, #T_e54e0_row7_col0, #T_e54e0_row7_col1, #T_e54e0_row7_col2, #T_e54e0_row7_col3, #T_e54e0_row8_col0, #T_e54e0_row9_col0, #T_e54e0_row9_col1, #T_e54e0_row9_col2, #T_e54e0_row9_col3, #T_e54e0_row9_col4, #T_e54e0_row9_col5, #T_e54e0_row9_col6, #T_e54e0_row10_col0, #T_e54e0_row10_col1, #T_e54e0_row10_col2, #T_e54e0_row10_col3, #T_e54e0_row10_col4, #T_e54e0_row10_col5, #T_e54e0_row10_col6, #T_e54e0_row11_col0, #T_e54e0_row11_col1, #T_e54e0_row11_col2, #T_e54e0_row11_col3, #T_e54e0_row11_col4, #T_e54e0_row11_col5, #T_e54e0_row11_col6, #T_e54e0_row12_col0, #T_e54e0_row12_col1, #T_e54e0_row12_col2, #T_e54e0_row12_col3, #T_e54e0_row12_col4, #T_e54e0_row12_col5, #T_e54e0_row12_col6, #T_e54e0_row13_col0, #T_e54e0_row13_col1, #T_e54e0_row13_col2, #T_e54e0_row13_col3, #T_e54e0_row13_col4, #T_e54e0_row13_col5, #T_e54e0_row13_col6, #T_e54e0_row14_col0, #T_e54e0_row14_col1, #T_e54e0_row14_col2, #T_e54e0_row14_col3, #T_e54e0_row14_col4, #T_e54e0_row14_col5, #T_e54e0_row14_col6, #T_e54e0_row15_col0, #T_e54e0_row15_col1, #T_e54e0_row15_col2, #T_e54e0_row15_col3, #T_e54e0_row15_col4, #T_e54e0_row15_col5, #T_e54e0_row15_col6, #T_e54e0_row16_col0, #T_e54e0_row16_col1, #T_e54e0_row16_col2, #T_e54e0_row16_col3, #T_e54e0_row16_col4, #T_e54e0_row16_col5, #T_e54e0_row16_col6, #T_e54e0_row17_col0, #T_e54e0_row17_col1, #T_e54e0_row17_col2, #T_e54e0_row17_col3, #T_e54e0_row17_col4, #T_e54e0_row17_col5, #T_e54e0_row17_col6 {
#   text-align: left;
# }
# #T_e54e0_row0_col1, #T_e54e0_row0_col2, #T_e54e0_row0_col3, #T_e54e0_row0_col4, #T_e54e0_row0_col5, #T_e54e0_row0_col6, #T_e54e0_row1_col2, #T_e54e0_row1_col4, #T_e54e0_row1_col5, #T_e54e0_row1_col6, #T_e54e0_row2_col4, #T_e54e0_row2_col5, #T_e54e0_row2_col6, #T_e54e0_row3_col4, #T_e54e0_row4_col1, #T_e54e0_row4_col2, #T_e54e0_row4_col3, #T_e54e0_row4_col4, #T_e54e0_row4_col5, #T_e54e0_row4_col6, #T_e54e0_row5_col4, #T_e54e0_row5_col5, #T_e54e0_row5_col6, #T_e54e0_row6_col1, #T_e54e0_row6_col2, #T_e54e0_row6_col3, #T_e54e0_row6_col4, #T_e54e0_row6_col5, #T_e54e0_row6_col6, #T_e54e0_row7_col4, #T_e54e0_row7_col5, #T_e54e0_row7_col6, #T_e54e0_row8_col1, #T_e54e0_row8_col2, #T_e54e0_row8_col3, #T_e54e0_row8_col4, #T_e54e0_row8_col5, #T_e54e0_row8_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e54e0_row0_col7, #T_e54e0_row1_col7, #T_e54e0_row2_col7, #T_e54e0_row3_col7, #T_e54e0_row5_col7, #T_e54e0_row6_col7, #T_e54e0_row8_col7, #T_e54e0_row9_col7, #T_e54e0_row10_col7, #T_e54e0_row11_col7, #T_e54e0_row12_col7, #T_e54e0_row13_col7, #T_e54e0_row14_col7, #T_e54e0_row15_col7, #T_e54e0_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_e54e0_row4_col7, #T_e54e0_row7_col7, #T_e54e0_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e54e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e54e0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e54e0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e54e0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e54e0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e54e0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e54e0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e54e0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_e54e0_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e54e0_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_e54e0_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_e54e0_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_e54e0_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_e54e0_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_e54e0_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_e54e0_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_e54e0_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_e54e0_row0_col7" class="data row0 col7" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_e54e0_level0_row1" class="row_heading level0 row1" >llar</th>
#       <td id="T_e54e0_row1_col0" class="data row1 col0" >Lasso Least Angle Regression</td>
#       <td id="T_e54e0_row1_col1" class="data row1 col1" >0.0002</td>
#       <td id="T_e54e0_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_e54e0_row1_col3" class="data row1 col3" >0.0003</td>
#       <td id="T_e54e0_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_e54e0_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_e54e0_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_e54e0_row1_col7" class="data row1 col7" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_e54e0_level0_row2" class="row_heading level0 row2" >lasso</th>
#       <td id="T_e54e0_row2_col0" class="data row2 col0" >Lasso Regression</td>
#       <td id="T_e54e0_row2_col1" class="data row2 col1" >0.0241</td>
#       <td id="T_e54e0_row2_col2" class="data row2 col2" >0.0010</td>
#       <td id="T_e54e0_row2_col3" class="data row2 col3" >0.0307</td>
#       <td id="T_e54e0_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_e54e0_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_e54e0_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_e54e0_row2_col7" class="data row2 col7" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_e54e0_level0_row3" class="row_heading level0 row3" >par</th>
#       <td id="T_e54e0_row3_col0" class="data row3 col0" >Passive Aggressive Regressor</td>
#       <td id="T_e54e0_row3_col1" class="data row3 col1" >6.6054</td>
#       <td id="T_e54e0_row3_col2" class="data row3 col2" >96.5341</td>
#       <td id="T_e54e0_row3_col3" class="data row3 col3" >8.0841</td>
#       <td id="T_e54e0_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_e54e0_row3_col5" class="data row3 col5" >0.0009</td>
#       <td id="T_e54e0_row3_col6" class="data row3 col6" >0.0007</td>
#       <td id="T_e54e0_row3_col7" class="data row3 col7" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_e54e0_level0_row4" class="row_heading level0 row4" >br</th>
#       <td id="T_e54e0_row4_col0" class="data row4 col0" >Bayesian Ridge</td>
#       <td id="T_e54e0_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_e54e0_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_e54e0_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_e54e0_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_e54e0_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_e54e0_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_e54e0_row4_col7" class="data row4 col7" >0.0030</td>
#     </tr>
#     <tr>
#       <th id="T_e54e0_level0_row5" class="row_heading level0 row5" >huber</th>
#       <td id="T_e54e0_row5_col0" class="data row5 col0" >Huber Regressor</td>
#       <td id="T_e54e0_row5_col1" class="data row5 col1" >0.1001</td>
#       <td id="T_e54e0_row5_col2" class="data row5 col2" >0.0592</td>
#       <td id="T_e54e0_row5_col3" class="data row5 col3" >0.1495</td>
#       <td id="T_e54e0_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_e54e0_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_e54e0_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_e54e0_row5_col7" class="data row5 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_e54e0_level0_row6" class="row_heading
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Id', 'Price_x', 'Age_08_04', 'KM',
#                                               'HP', 'Automatic', 'CC', 'Doors',
#                                               'Cylinders', 'Gears', 'Weight'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('trained_model', LinearRegression(n_jobs=-1))]),
#  'best_model.pkl')
